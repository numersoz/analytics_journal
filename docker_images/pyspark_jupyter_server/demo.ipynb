# %%
import requests
from hdfs import InsecureClient
from pyspark.sql import SparkSession

# Download file:
url = "https://msi.nga.mil/api/publications/download?type=view&key=16920959/SFH00000/UpdatedPub150.csv"
local_csv_path = "/tmp/UpdatedPub150.csv"
response = requests.get(url, verify=False)

with open(local_csv_path, 'wb') as file:
    file.write(response.content)

# Connect to HDFS:
hdfs_client = InsecureClient('http://hdfs-namenode:9870', user='root')

# Upload the file to HDFS:
hdfs_path = '/data/UpdatedPub150.csv'
hdfs_client.upload(hdfs_path, local_csv_path, overwrite=True)

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Read CSV with PySpark") \
    .config("spark.executor.memory", "2g") \
    .config("spark.executor.cores", "1") \
    .config("spark.cores.max", "1") \
    .config("spark.driver.memory", "2g") \
    .master("spark://spark-master:7077") \
    .getOrCreate()

# Define the path to the CSV file in HDFS:
hdfs_csv_path = "hdfs://hdfs-namenode:8020/data/UpdatedPub150.csv"

# Read the CSV file into a DataFrameL
df = spark.read.csv(hdfs_csv_path, header=True, inferSchema=True)

# Create a temporary SQL viewL
df.createOrReplaceTempView("temporary_view")

# Query the temporary view using SQL
query_result = spark.sql("SELECT `Main Port Name`, `Latitude`, `Longitude` FROM temporary_view LIMIT 10")

# Show the result of the query
query_result.show()

# Optional: Print the schema of the DataFrame
df.printSchema()
# Out:
# /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'msi.nga.mil'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# +--------------------+----------+----------+
# |      Main Port Name|  Latitude| Longitude|
# +--------------------+----------+----------+
# |              Maurer| 40.533333|    -74.25|
# |             Iharana|    -13.35|      50.0|
# |             Andoany|     -13.4|      48.3|
# |         Chake Chake|     -5.25| 39.766667|
# |   Mjimwema Terminal| -6.816667| 39.366667|
# |      Delta Terminal|     36.85| 36.166667|
# |  Cinta Oil Terminal|      -5.5|106.233333|
# |        Europa Point| 36.133333|     -5.35|
# |          New Harbor| 43.866667|-69.483333|
# |Dtse / Gegua Oil ...|-22.816667|    -43.15|
# +--------------------+----------+----------+
#
# root
#  |-- OID_: double (nullable = true)
#  |-- World Port Index Number: double (nullable = true)
#  |-- Region Name: string (nullable = true)
#  |-- Main Port Name: string (nullable = true)
#  |-- Alternate Port Name: string (nullable = true)
#  |-- UN/LOCODE: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- World Water Body: string (nullable = true)
#  |-- IHO S-130 Sea Area: string (nullable = true)
#  |-- Sailing Direction or Publication: string (nullable = true)
#  |-- Publication Link: string (nullable = true)
#  |-- Standard Nautical Chart: string (nullable = true)
#  |-- IHO S-57 Electronic Navigational Chart: string (nullable = true)
#  |-- IHO S-101 Electronic Navigational Chart: string (nullable = true)
#  |-- Digital Nautical Chart: string (nullable = true)
#  |-- Tidal Range (m): double (nullable = true)
#  |-- Entrance Width (m): double (nullable = true)
#  |-- Channel Depth (m): double (nullable = true)
#  |-- Anchorage Depth (m): double (nullable = true)
#  |-- Cargo Pier Depth (m): double (nullable = true)
#  |-- Oil Terminal Depth (m): double (nullable = true)
#  |-- Liquified Natural Gas Terminal Depth (m): double (nullable = true)
#  |-- Maximum Vessel Length (m): double (nullable = true)
#  |-- Maximum Vessel Beam (m): double (nullable = true)
#  |-- Maximum Vessel Draft (m): double (nullable = true)
#  |-- Offshore Maximum Vessel Length (m): double (nullable = true)
#  |-- Offshore Maximum Vessel Beam (m): double (nullable = true)
#  |-- Offshore Maximum Vessel Draft (m): double (nullable = true)
#  |-- Harbor Size: string (nullable = true)
#  |-- Harbor Type: string (nullable = true)
#  |-- Harbor Use: string (nullable = true)
#  |-- Shelter Afforded: string (nullable = true)
#  |-- Entrance Restriction - Tide: string (nullable = true)
#  |-- Entrance Restriction - Heavy Swell: string (nullable = true)
#  |-- Entrance Restriction - Ice: string (nullable = true)
#  |-- Entrance Restriction - Other: string (nullable = true)
#  |-- Overhead Limits: string (nullable = true)
#  |-- Underkeel Clearance Management System: string (nullable = true)
#  |-- Good Holding Ground: string (nullable = true)
#  |-- Turning Area: string (nullable = true)
#  |-- Port Security: string (nullable = true)
#  |-- Estimated Time of Arrival Message: string (nullable = true)
#  |-- Quarantine - Pratique: string (nullable = true)
#  |-- Quarantine - Sanitation: string (nullable = true)
#  |-- Quarantine - Other: string (nullable = true)
#  |-- Traffic Separation Scheme: string (nullable = true)
#  |-- Vessel Traffic Service: string (nullable = true)
#  |-- First Port of Entry: string (nullable = true)
#  |-- US Representative: string (nullable = true)
#  |-- Pilotage - Compulsory: string (nullable = true)
#  |-- Pilotage - Available: string (nullable = true)
#  |-- Pilotage - Local Assistance: string (nullable = true)
#  |-- Pilotage - Advisable: string (nullable = true)
#  |-- Tugs - Salvage: string (nullable = true)
#  |-- Tugs - Assistance: string (nullable = true)
#  |-- Communications - Telephone: string (nullable = true)
#  |-- Communications - Telefax: string (nullable = true)
#  |-- Communications - Radio: string (nullable = true)
#  |-- Communications - Radiotelephone: string (nullable = true)
#  |-- Communications - Airport: string (nullable = true)
#  |-- Communications - Rail: string (nullable = true)
#  |-- Search and Rescue: string (nullable = true)
#  |-- NAVAREA: string (nullable = true)
#  |-- Facilities - Wharves: string (nullable = true)
#  |-- Facilities - Anchorage: string (nullable = true)
#  |-- Facilities - Dangerous Cargo Anchorage: string (nullable = true)
#  |-- Facilities - Med Mooring: string (nullable = true)
#  |-- Facilities - Beach Mooring: string (nullable = true)
#  |-- Facilities - Ice Mooring: string (nullable = true)
#  |-- Facilities - Ro-Ro: string (nullable = true)
#  |-- Facilities - Solid Bulk: string (nullable = true)
#  |-- Facilities - Liquid Bulk: string (nullable = true)
#  |-- Facilities - Container: string (nullable = true)
#  |-- Facilities - Breakbulk: string (nullable = true)
#  |-- Facilities - Oil Terminal: string (nullable = true)
#  |-- Facilities - LNG Terminal: string (nullable = true)
#  |-- Facilities - Other: string (nullable = true)
#  |-- Medical Facilities: string (nullable = true)
#  |-- Garbage Disposal: string (nullable = true)
#  |-- Chemical Holding Tank Disposal: string (nullable = true)
#  |-- Degaussing: string (nullable = true)
#  |-- Dirty Ballast Disposal: string (nullable = true)
#  |-- Cranes - Fixed: string (nullable = true)
#  |-- Cranes - Mobile: string (nullable = true)
#  |-- Cranes - Floating: string (nullable = true)
#  |-- Cranes Container: string (nullable = true)
#  |-- Lifts - 100+ Tons: string (nullable = true)
#  |-- Lifts - 50-100 Tons: string (nullable = true)
#  |-- Lifts - 25-49 Tons: string (nullable = true)
#  |-- Lifts - 0-24 Tons: string (nullable = true)
#  |-- Services - Longshoremen: string (nullable = true)
#  |-- Services - Electricity: string (nullable = true)
#  |-- Services -Steam: string (nullable = true)
#  |-- Services - Navigation Equipment: string (nullable = true)
#  |-- Services - Electrical Repair: string (nullable = true)
#  |-- Services - Ice Breaking: string (nullable = true)
#  |-- Services -Diving: string (nullable = true)
#  |-- Supplies - Provisions: string (nullable = true)
#  |-- Supplies - Potable Water: string (nullable = true)
#  |-- Supplies - Fuel Oil: string (nullable = true)
#  |-- Supplies - Diesel Oil: string (nullable = true)
#  |-- Supplies - Aviation Fuel: string (nullable = true)
#  |-- Supplies - Deck: string (nullable = true)
#  |-- Supplies - Engine: string (nullable = true)
#  |-- Repairs: string (nullable = true)
#  |-- Dry Dock: string (nullable = true)
#  |-- Railway: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
